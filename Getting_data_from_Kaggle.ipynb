# %%
import sys
import os
import json
import zipfile

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import files
files.upload()  #this will prompt you to upload the kaggle.json
# Out:
#      <input type="file" id="files-6d510db9-f9b0-4777-b807-04f465eb5f4d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d510db9-f9b0-4777-b807-04f465eb5f4d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"jaideepgadekar28","key":"1604a3fd3c1979805dabc7579061ce1d"}'}

# %%
# !pip install -q kaggle
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !ls ~/.kaggle
# !chmod 600 /root/.kaggle/kaggle.json  # set permission
# Out:
# kaggle.json

# %%
# !kaggle datasets download -d wobotintelligence/face-mask-detection-dataset -p /content/gdrive/My\ Drive/Face_mask_detection/face_mask_data
# Out:
# ...
# 100% 2.49G/2.50G [00:29<00:00, 93.9MB/s]
# 100% 2.50G/2.50G [00:29<00:00, 89.6MB/s]

# %%
os.chdir('gdrive/MyDrive/Face_mask_detection/face_mask_data')

# %%
with zipfile.ZipFile("/content/gdrive/MyDrive/Face_mask_detection/face_mask_data/face-mask-detection-dataset.zip","r") as zip_ref:
    zip_ref.extractall("/content/gdrive/MyDrive/Face_mask_detection/face_mask_data")

# %%
# !kaggle datasets download -d wobotintelligence/face-mask-detection-dataset -p /content/gdrive/My\ Drive/Face_mask_detection/face_mask_data
# Out:
# ['0001.jpg',
#  '0002.png',
#  '0003.jpg',
#  '0004.jpg',
#  '0005.jpg',
#  '0006.jpg',
#  '0007.jpg',
#  '0009.jpg',
#  '0010.jpg',
#  '0011.jpg',
#  '0012.jpg',
#  '0014.jpg',
#  '0015.jpg',
#  '0017.jpg',
#  '0018.jpg',
#  '0019.jpg',
#  '0020.jpg',
#  '0021.jpg',
#  '0022.jpg',
#  '0023.jpg',
#  '0024.jpg',
#  '0025.jpg',
#  '0026.jpg',
#  '0027.jpg',
#  '0028.jpg',
#  '0029.jpg',
#  '0030.jpg',
#  '0031.jpg',
#  '0032.jpg',
#  '0033.jpg',
#  '0034.jpg',
#  '0035.jpg',
#  '0036.jpg',
#  '0037.jpg',
#  '0038.jpg',
#  '0039.jpg',
#  '0040.jpg',
#  '0041.jpg',
#  '0042.jpg',
#  '0043.jpg',
#  '0044.jpg',
#  '0045.jpg',
#  '0046.jpg',
#  '0048.jpg',
#  '0049.jpg',
#  '0050.jpg',
#  '0051.jpg',
#  '0052.jpeg',
#  '0053.jpg',
#  '0054.jpg',
#  '0055.jpg',
#  '0056.jpg',
#  '0057.jpg',
#  '0058.jpg',
#  '0059.jpg',
#  '0060.jpg',
#  '0061.jpg',
#  '0062.jpg',
#  '0063.jpg',
#  '0064.jpg',
#  '0065.jpg',
#  '0066.jpg',
#  '0067.jpg',
#  '0068.jpg',
#  '0069.jpg',
#  '0070.jpg',
# ...

# %%
print(len(os.listdir('/content/gdrive/MyDrive/Face_mask_detection/face_mask_data/data/images')))
# Out:
# 6024

# %%
# !kaggle datasets download -d jessicali9530/celeba-dataset/image_align_celeba/image_align_celeba -p /content/gdrive/My\ Drive/Face_mask_detection/face_detection_data
# Out:
# ...
#  99% 1.32G/1.33G [00:11<00:00, 139MB/s]
# 100% 1.33G/1.33G [00:11<00:00, 123MB/s]

# %%
os.chdir('/content/gdrive/MyDrive/Face_mask_detection/face_mask_data')

# %%
with zipfile.ZipFile("/content/gdrive/MyDrive/Face_mask_detection/face_detection_data/celeba-dataset.zip","r") as zip_ref:
    zip_ref.extractall("/content/gdrive/MyDrive/Face_mask_detection/face_detection_data")

# %%
print(len(os.listdir('/content/gdrive/MyDrive/Face_mask_detection/face_detection_data/img_align_celeba/img_align_celeba')))
# Out:
# 202599
